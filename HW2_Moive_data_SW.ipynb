# %% [markdown]
# ### Spark HW2 Moive Recommendation
# In this notebook, we will use an Alternating Least Squares (ALS) algorithm with Spark APIs to predict the ratings for the movies in [MovieLens small dataset](https://grouplens.org/datasets/movielens/latest/)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os
os.environ["PYSPARK_PYTHON"] = "python3"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.library.installPyPI("mlflow")
dbutils.library.restartPython()
import mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Sat May 30 23:02:44 2020 py4j imported
# </div>

# %% [markdown]
# ## Part1: Data ETL and Data Exploration

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("moive analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df = spark.read.load("/FileStore/tables/movies.csv", format='csv', header = True)
ratings_df = spark.read.load("/FileStore/tables/ratings.csv", format='csv', header = True)
links_df = spark.read.load("/FileStore/tables/links.csv", format='csv', header = True)
tags_df = spark.read.load("/FileStore/tables/tags.csv", format='csv', header = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------------------+
# movieId|               title|              genres|
# +-------+--------------------+--------------------+
#       1|    Toy Story (1995)|Adventure|Animati...|
#       2|      Jumanji (1995)|Adventure|Childre...|
#       3|Grumpier Old Men ...|      Comedy|Romance|
#       4|Waiting to Exhale...|Comedy|Drama|Romance|
#       5|Father of the Bri...|              Comedy|
# +-------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
ratings_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+---------+
# userId|movieId|rating|timestamp|
# +------+-------+------+---------+
#      1|      1|   4.0|964982703|
#      1|      3|   4.0|964981247|
#      1|      6|   4.0|964982224|
#      1|     47|   5.0|964983815|
#      1|     50|   5.0|964982931|
# +------+-------+------+---------+
# only showing top 5 rows
#
# </div>

# %%
links_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+
# movieId| imdbId|tmdbId|
# +-------+-------+------+
#       1|0114709|   862|
#       2|0113497|  8844|
#       3|0113228| 15602|
#       4|0114885| 31357|
#       5|0113041| 11862|
# +-------+-------+------+
# only showing top 5 rows
#
# </div>

# %%
tags_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+---------------+----------+
# userId|movieId|            tag| timestamp|
# +------+-------+---------------+----------+
#      2|  60756|          funny|1445714994|
#      2|  60756|Highly quotable|1445714996|
#      2|  60756|   will ferrell|1445714992|
#      2|  89774|   Boxing story|1445715207|
#      2|  89774|            MMA|1445715200|
# +------+-------+---------------+----------+
# only showing top 5 rows
#
# </div>

# %%
tmp1 = ratings_df.groupBy("userID").count().toPandas()['count'].min()
tmp2 = ratings_df.groupBy("movieId").count().toPandas()['count'].min()
print('For the users that rated movies and the movies that were rated:')
print('Minimum number of ratings per user is {}'.format(tmp1))
print('Minimum number of ratings per movie is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/types.py:1636: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   return pa.schema(fields)
# For the users that rated movies and the movies that were rated:
# Minimum number of ratings per user is 20
# Minimum number of ratings per movie is 1
# </div>

# %%
tmp1 = sum(ratings_df.groupBy("movieId").count().toPandas()['count'] == 1)
tmp2 = ratings_df.select('movieId').distinct().count()
print('{} out of {} movies are rated by only one user'.format(tmp1, tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/types.py:1636: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   return pa.schema(fields)
# 3446 out of 9724 movies are rated by only one user
# </div>

# %% [markdown]
# ## Part 1: Spark SQL and OLAP

# %%
movies_df.registerTempTable("movies")
ratings_df.registerTempTable("ratings")
links_df.registerTempTable("links")
tags_df.registerTempTable("tags")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/dataframe.py:141: DeprecationWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   &#34;Deprecated in 2.0, use createOrReplaceTempView instead.&#34;, DeprecationWarning)
# </div>

# %% [markdown]
# ### Q1: The number of Users

# %%
# %sql 
select count( distinct userId  )
from ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT userId)</th></tr></thead><tbody><tr><td>610</td></tr></tbody></table></div>

# %% [markdown]
# ### Q2: The number of Movies

# %%
# %sql 
select count(distinct movieId)
from movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT movieId)</th></tr></thead><tbody><tr><td>9742</td></tr></tbody></table></div>

# %% [markdown]
# ### Q3:  How many movies are rated by users? List movies not rated before

# %%
# %sql 
select count(*)
from movies 
where movieID in (
  select distinct movieID
  from ratings
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>9724</td></tr></tbody></table></div>

# %%
# %sql 
select *
from movies 
where movieID in (
  select distinct movieID
  from ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody><tr><td>1</td><td>Toy Story (1995)</td><td>Adventure|Animation|Children|Comedy|Fantasy</td></tr><tr><td>2</td><td>Jumanji (1995)</td><td>Adventure|Children|Fantasy</td></tr><tr><td>3</td><td>Grumpier Old Men (1995)</td><td>Comedy|Romance</td></tr><tr><td>4</td><td>Waiting to Exhale (1995)</td><td>Comedy|Drama|Romance</td></tr><tr><td>5</td><td>Father of the Bride Part II (1995)</
1995)</td><td>Comedy|Drama|Romance</td></tr><tr><td>53</td><td>Lamerica (1994)</td><td>Adventure|Drama</td></tr><tr><td>54</td><td>Big Green, The (1 ...

# %%
# %sql 
select *
from movies 
where movieID not in (
  select distinct movieID
  from ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody><tr><td>1076</td><td>Innocents, The (1961)</td><td>Drama|Horror|Thriller</td></tr><tr><td>2939</td><td>Niagara (1953)</td><td>Drama|Thriller</td></tr><tr><td>3338</td><td>For All Mankind (1989)</td><td>Documentary</td></tr><tr><td>3456</td><td>Color of Paradise, The (Rang-e khoda) (1999)</td><td>Drama</td></tr><tr><td>4194</td><td>I Know Where I'm Going! (1945)</td><td>Drama|Romance|War</td></tr><tr><td>5721</td><td>Chosen, The (1981)</td><td>Drama</td></tr><tr><td>6668</td><td>Road Home, The (Wo de fu qin mu qin) (1999)</td><td>Drama|Romance</td></tr><tr><td>6849</td><td>Scrooge (1970)</td><td>Drama|Fantasy|Musical</td></tr><tr><td>7020</td><td>Proof (1991)</td><td>Comedy|Drama|Romance</td></tr><tr><td>7792</td><td>Parallax View, The (1974)</td><td>Thriller</td></tr><tr><td>8765</td><td>This Gun for Hire (1942)</td><td>Crime|Film-Noir|Thriller</td></tr><tr><td>25855</td><td>Roaring Twenties, The (1939)</td><td>Crime|Drama|Thriller</td></tr><tr><td>26085</td><td>Mutiny on the Bounty (1962)</td><td>Adventure|Drama|Romance</td></tr><tr><td>30892</td><td>In the Realms of the Unreal (2004)</td><td>Animation|Documentary</td></tr><tr><td>32160</td><td>Twentieth Century (1934)</td><td>Comedy</td></tr><tr><td>32371</td><td>Call Northside 777 (1948)</td><td>Crime|Drama|Film-Noir</td></tr><tr><td>34482</td><td>Browning Version, The (1951)</td><td>Drama</td></tr><tr><td>85565</td><td>Chalet Girl (2011)</td><td>Comedy|Romance</td></tr></tbody></table></div>

# %%
# %sql 
select count(*)
from movies 
where movieID not in (
  select distinct movieID
  from ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>18</td></tr></tbody></table></div>

# %% [markdown]
# ### Q4: List Movie Genres

# %%
# %sql
select distinct genres
from movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genres</th></tr></thead><tbody><tr><td>Comedy|Horror|Thriller</td></tr><tr><td>Adventure|Sci-Fi|Thriller</td></tr><tr><td>Action|Adventure|Drama|Fantasy</td></tr><tr><td>Action|Drama|Horror</td></tr><tr><td>Action|Animation|Comedy|Sci-Fi</td></tr><tr><td>Animation|Children|Drama|Musical|Romance</td></tr><tr><td>Action|Adventure|Drama</td></tr><tr><td>Adventure|Sci-Fi</td></tr><tr><td>Documentary|Musical|IMAX</td></tr><tr><td>Adventure|Children|Fantasy|Sci-Fi|Thriller</td></tr><tr><td>Adventure|Animation</td></tr><tr><td>Musical|Romance|War</td></tr><tr><td>Action|Adventure|Fantasy|Romance</td></tr><tr><td>Adventure|Children|Drama|Fantasy|IMAX</td></tr><tr><td
romance</td></tr><tr><td>Adventure|Animation|Children|Comedy|Fantasy|Romance</td></tr><tr><td>Comedy|Crime|Drama|War</td></tr><tr><td>Adventure|Animation|Fantasy|Romance</td></tr><tr><td>Drama|Fantasy|Horror|Romance|Thriller</td></tr><tr><td>Action|Sci-Fi|Thriller|Western|IMAX</td></tr><tr><td>Animation|Children</td></tr><tr><td>Action|Crime|Mystery|Thriller</td></tr><tr><td>Comedy|Romance|Sci-Fi</td></tr><tr><td>Adventure|War|Western</td></tr><tr><td>Action|Animation|Comedy|Fantasy</td></tr><tr><td>Comedy|Horror|Romance</td></tr><tr><td>Comedy|Drama|Musical</td></tr><tr><td>Drama|Film-Noir|Mystery|Roma ...

# %% [markdown]
# ## 方法一： 按照pandas dataframe来做getdummies split （先把spark.dataframe convert成pandas.dataframe， 再转化回来）
# ## 但这个问题除了麻烦以外，还把数据压得很平，把行变成了列。不是很好统计。

# %%
movies_pd=movies_df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
genres_pd=movies_pd['genres'].str.get_dummies(sep='|')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
movies_pd=pd.concat([movies_pd,genres_pd],axis=1)
movies_pd=movies_pd.drop(columns=['genres'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_pd.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>movieId</th>
#       <th>title</th>
#       <th>(no genres listed)</th>
#       <th>Action</th>
#       <th>Adventure</th>
#       <th>Animation</th>
#       <th>Children</th>
#       <th>Comedy</th>
#       <th>Crime</th>
#       <th>Documentary</th>
#       <th>Drama</th>
#       <th>Fantasy</th>
#       <th>Film-Noir</th>
#       <th>Horror</th>
#       <th>IMAX</th>
#       <th>Musical</th>
#       <th>Mystery</th>
#       <th>Romance</th>
#       <th>Sci-Fi</th>
#       <th>Thriller</th>
#       <th>War</th>
#       <th>Western</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Toy Story (1995)</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Jumanji (1995)</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Grumpier Old Men (1995)</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
new_movies_df=spark.createDataFrame(movies_pd)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(new_movies_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>(no genres listed)</th><th>Action</th><th>Adventure</th><th>Animation</th><th>Children</th><th>Comedy</th><th>Crime</th><th>Documentary</th><th>Drama</th><th>Fantasy</th><th>Film-Noir</th><th>Horror</th><th>IMAX</th><th>Musical</th><th>Mystery</th><th>Romance</th><th>Sci-Fi</th><th>Thriller</th><th>War</th><th>Western</th></tr></thead><tbody><tr><td>1</td><td>Toy Story (1995)</td><td>0</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>2</td><td>Jumanji (1995)</td><td>0</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>3</td><td>Grumpier Old Men (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>4</td><td>Waiting to Exhale (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>5</td><td>Father of the Bride Part II (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>6</td><td>Heat (1995)</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>7</td><td>Sabrina (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>8</td><td>Tom and Huck (1995)</td><td>0</td><td>0</td><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>9</td><td>Sudden Death (1995)</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>10</td><td>GoldenEye (1995)</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td>11</td><td>American President, The (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>12</td><td>Dracula: Dead and Loving It (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>13</td><td>Balto (1995)</td><td>0</td><td>0</td><td>1</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>14</td><td>Nixon (1995)</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>15</td><td>Cutthroat Isl ...

# %% [markdown]
# ## 方法二：经过多方搜索，我发现sql中有一个cross apply的方法，可以把， a b，c这样的变成a b和a c两行。
# ## 然而遗憾的是spark里并没有这个function。后来老师说可以用explode function。看似可以达到我想要的结果。参考了下面的文章
# https://sparkbyexamples.com/pyspark/pyspark-explode-array-and-map-columns-

# %%
spark.catalog.listTables()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [Table(name=&#39;diamonds&#39;, database=&#39;default&#39;, description=None, tableType=&#39;EXTERNAL&#39;, isTemporary=False),
#  Table(name=&#39;links&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;movies&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;ratings&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;tags&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True)]</div>

# %%
from pyspark.sql.functions import explode, col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import split
movies_df=movies_df.withColumn("genres",split(col("genres"),"\|"))
movies_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;&gt;:2: DeprecationWarning: invalid escape sequence \|
# &lt;&gt;:2: DeprecationWarning: invalid escape sequence \|
# &lt;command-1230591079671496&gt;:2: DeprecationWarning: invalid escape sequence \|
#   movies_df=movies_df.withColumn(&#34;genres&#34;,split(col(&#34;genres&#34;),&#34;\|&#34;))
# +-------+--------------------+--------------------+
# movieId|               title|              genres|
# +-------+--------------------+--------------------+
#       1|    Toy Story (1995)|[Adventure, Anima...|
#       2|      Jumanji (1995)|[Adventure, Child...|
#       3|Grumpier Old Men ...|   [Comedy, Romance]|
#       4|Waiting to Exhale...|[Comedy, Drama, R...|
#       5|Father of the Bri...|            [Comedy]|
#       6|         Heat (1995)|[Action, Crime, T...|
#       7|      Sabrina (1995)|   [Comedy, Romance]|
#       8| Tom and Huck (1995)|[Adventure, Child...|
#       9| Sudden Death (1995)|            [Action]|
#      10|    GoldenEye (1995)|[Action, Adventur...|
#      11|American Presiden...|[Comedy, Drama, R...|
#      12|Dracula: Dead and...|    [Comedy, Horror]|
#      13|        Balto (1995)|[Adventure, Anima...|
#      14|        Nixon (1995)|             [Drama]|
#      15|Cutthroat Island ...|[Action, Adventur...|
#      16|       Casino (1995)|      [Crime, Drama]|
#      17|Sense and Sensibi...|    [Drama, Romance]|
#      18|   Four Rooms (1995)|            [Comedy]|
#      19|Ace Ventura: When...|            [Comedy]|
#      20|  Money Train (1995)|[Action, Comedy, ...|
# +-------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
new_movie_df =movies_df.select(movies_df.movieId,movies_df.title,explode(movies_df.genres).alias("genres"))
new_movie_df.printSchema()
new_movie_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- movieId: string (nullable = true)
# -- title: string (nullable = true)
# -- genres: string (nullable = true)
#
# +-------+--------------------+---------+
# movieId|               title|   genres|
# +-------+--------------------+---------+
#       1|    Toy Story (1995)|Adventure|
#       1|    Toy Story (1995)|Animation|
#       1|    Toy Story (1995)| Children|
#       1|    Toy Story (1995)|   Comedy|
#       1|    Toy Story (1995)|  Fantasy|
#       2|      Jumanji (1995)|Adventure|
#       2|      Jumanji (1995)| Children|
#       2|      Jumanji (1995)|  Fantasy|
#       3|Grumpier Old Men ...|   Comedy|
#       3|Grumpier Old Men ...|  Romance|
#       4|Waiting to Exhale...|   Comedy|
#       4|Waiting to Exhale...|    Drama|
#       4|Waiting to Exhale...|  Romance|
#       5|Father of the Bri...|   Comedy|
#       6|         Heat (1995)|   Action|
#       6|         Heat (1995)|    Crime|
#       6|         Heat (1995)| Thriller|
#       7|      Sabrina (1995)|   Comedy|
#       7|      Sabrina (1995)|  Romance|
#       8| Tom and Huck (1995)|Adventure|
# +-------+--------------------+---------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### Q5: Movie for Each Category

# %%
new_movie_df.registerTempTable("new_movies")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select genres, count(*) as number
from new_movies
group by genres
order by number desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
tr><tr><td>Hard Target (1993)</td></tr><tr><td>Jimmy Hollywood (1994)</td></tr><tr><td>Judgment Night (1993)</td></tr><tr><td>Killing Zoe (1994)</td></tr><tr><td>Menace II Society (1993)</td></tr><tr><td>Perfect World, A (1993)</td></tr><tr><td>RoboCop 3 (1993)</td></tr><tr><td>Romeo Is Bleeding (1993)</td></tr><tr><td>Serial Mom (1994)</td></tr><tr><td>Striking Distance (1993)</td></tr><tr><td>True Romance (1993)</td></tr><tr><td>Escort, The (Scorta, La) (1993)</td></tr><tr><td>Batman (1989)</td></tr><tr><td>Silence of the Lambs, The (1991)</td></tr><tr><td>Love and a .45 (1994)</td></tr><tr><td>Fargo (1996)</td></tr><tr><td>Primal Fear (1996)</td></tr><tr><td>Courage Under Fire (1996)</td></tr><tr><td>Substitute, The (1996)</td></tr><tr><td>Mulholland Falls (1996)</td></tr><tr><td>Heaven's Prisoners (1996)</td></tr><tr><td>Striptease (1996)</td></tr><tr><td>Trainspotting (1996)</td></tr><tr><td>American Buffalo (1996)</td></tr><tr><td>Ransom (1996)</td></tr><tr><td>Godfather, The (1972)</td></tr><tr><td>Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992)</td></tr><tr><td>Bound (1996)</td></tr><tr><td>Carpool (1996)</td></tr><tr><td>Kansas City (1996)</td></tr><tr><td>Nothing to Lose (1994)</td></tr><tr><td>Supercop 2 (Project S) (Chao ji ji hua) (1993)</td></tr><tr><td>Bulletproof (1996)</td></tr><tr><td>Some Like It Hot (1959)</td></tr><tr><td>Charade (1963)</td></tr><tr><td>To Catch a Thief (1955)</td></tr><tr><td>Laura (1944)</td></tr><tr><td>Thin Man, The (1934)</td></tr><tr><td>Beat the Devil (1953)</td></tr><tr><td>Last Man Standing (1996)</td></tr><tr><td>Set It Off (1996)</td></tr><tr><td>2 Days ...

# %% [markdown]
# ## Part2: Spark ALS based approach for training model
# We will use an Spark ML to predict the ratings, so let's reload "ratings.csv" using ``sc.textFile`` and then convert it to the form of (user, item, rating) tuples.

# %%
new_ratings_df= sc.textFile("/FileStore/tables/ratings.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_ratings_df.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 2</div>

# %%
new_ratings_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 100837</div>

# %%
movie_ratings=ratings_df.drop('timestamp')
movie_ratings.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+
# userId|movieId|rating|
# +------+-------+------+
#      1|      1|   4.0|
#      1|      3|   4.0|
#      1|      6|   4.0|
#      1|     47|   5.0|
#      1|     50|   5.0|
#      1|     70|   3.0|
#      1|    101|   5.0|
#      1|    110|   4.0|
#      1|    151|   5.0|
#      1|    157|   5.0|
#      1|    163|   5.0|
#      1|    216|   5.0|
#      1|    223|   3.0|
#      1|    231|   5.0|
#      1|    235|   4.0|
#      1|    260|   5.0|
#      1|    296|   3.0|
#      1|    316|   3.0|
#      1|    333|   5.0|
#      1|    349|   4.0|
# +------+-------+------+
# only showing top 20 rows
#
# </div>

# %%
movie_ratings.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- userId: string (nullable = true)
# -- movieId: string (nullable = true)
# -- rating: string (nullable = true)
#
# </div>

# %%
# Data type convert
from pyspark.sql.types import IntegerType, FloatType
movie_ratings = movie_ratings.withColumn("userId", movie_ratings["userId"].cast(IntegerType()))
movie_ratings = movie_ratings.withColumn("movieId", movie_ratings["movieId"].cast(IntegerType()))
movie_ratings = movie_ratings.withColumn("rating", movie_ratings["rating"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movie_ratings.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+
# userId|movieId|rating|
# +------+-------+------+
#      1|      1|   4.0|
#      1|      3|   4.0|
#      1|      6|   4.0|
#      1|     47|   5.0|
#      1|     50|   5.0|
#      1|     70|   3.0|
#      1|    101|   5.0|
#      1|    110|   4.0|
#      1|    151|   5.0|
#      1|    157|   5.0|
#      1|    163|   5.0|
#      1|    216|   5.0|
#      1|    223|   3.0|
#      1|    231|   5.0|
#      1|    235|   4.0|
#      1|    260|   5.0|
#      1|    296|   3.0|
#      1|    316|   3.0|
#      1|    333|   5.0|
#      1|    349|   4.0|
# +------+-------+------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### ALS Model Selection and Evaluation
#
# With the ALS model, we can use a grid search to find the optimal hyperparameters.

# %%
# import package
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator,ParamGridBuilder
from pyspark.sql import Row
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create test and train set
(training,test)=movie_ratings.randomSplit([0.8,0.2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create ALS model
# Build the recommendation model using ALS on the training data
# Note we set cold start strategy to 'drop' to ensure we don't get NaN evaluation metrics
als = ALS(maxIter=5, rank=5, regParam=0.09, userCol="userId", itemCol="movieId", ratingCol="rating", coldStartStrategy="drop" )
model = als.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# #Fit ALS model to training data
# Define evaluator as RMSE
predictions = model.transform(training)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root-mean-square error = 0.6467764675290799
# </div>

# %%
# #Fit ALS model to testing data
# Define evaluator as RMSE
predictions_test = model.transform(test)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions_test)
print("Root-mean-square error = " + str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root-mean-square error = 0.8912734368253553
# </div>

# %%
#Tune model using ParamGridBuilder
paramGrid = ParamGridBuilder()\
  .addGrid(als.rank,  [1,3] )\
  .addGrid(als.maxIter, [5,10] )\
  .addGrid(als.regParam,[ 0.05, .1] )\
  .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
 # Build Cross validation 
cv = CrossValidator(estimator=als, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=3)

# Confirm cv was built
print(cv)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">CrossValidator_783741b99122
# </div>

# %%
#Extract best model from the tuning exercise using ParamGridBuilder
#Fit cross validator to the 'train' dataset
best_model =cv.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">MLlib will automatically track trials in MLflow. After your tuning fit() call has completed, view the MLflow UI to see logged runs.
# </div>

# %%
best_model = best_model.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(type(model))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pyspark.ml.recommendation.ALSModel&#39;&gt;
# </div>

# %% [markdown]
# ### Model testing
# And finally, make a prediction and check the testing error.

# %%
# #Fit ALS model to training data
# Define evaluator as RMSE
new_predictions = best_model.transform(training)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Generate predictions and evaluate using RMSE
new_rmse = evaluator.evaluate(new_predictions)
print("Root-mean-square error = " + str(new_rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root-mean-square error = 0.6910307592150805
# </div>

# %%
#Print evaluation metrics and model parameters
print ("RMSE = "+str(new_rmse))
print ("**Best Model**")
print (" Rank:"+str(best_model.rank))
print (" MaxIter:"+str(best_model._java_obj.parent().getMaxIter()))
print (" RegParam:"+str(best_model._java_obj.parent().getRegParam()))
# Print best_model
print(type(best_model))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.6910307592150805
# **Best Model**
#  Rank:3
#  MaxIter:10
#  RegParam:0.1
# &lt;class &#39;pyspark.ml.recommendation.ALSModel&#39;&gt;
# </div>

# %%
# #Fit best model to testing data
# Define evaluator as RMSE
predictions_test_bestModel = best_model.transform(test)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions_test_bestModel)
print("Root-mean-square error = " + str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root-mean-square error = 0.8807294999789852
# </div>

# %%
predictions_test_bestModel.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+----------+
# userId|movieId|rating|prediction|
# +------+-------+------+----------+
#    436|    471|   3.0| 3.5580633|
#    602|    471|   4.0| 3.3666139|
#     91|    471|   1.0|  2.993339|
#    372|    471|   3.0| 3.0958042|
#    610|    471|   4.0| 3.8647404|
#    520|    471|   5.0| 3.8863053|
#    171|    471|   3.0| 4.5375347|
#    273|    471|   5.0| 3.5945852|
#    448|    471|   4.0| 3.2085583|
#    312|    471|   4.0| 3.6635547|
#    608|    471|   1.5| 3.4781468|
#    104|    471|   4.5| 3.6131032|
#    159|   1088|   4.0| 3.0535617|
#    474|   1088|   3.5| 2.8828268|
#    479|   1088|   4.0| 2.8670397|
#     64|   1088|   4.0| 3.0780296|
#     41|   1088|   1.5| 2.6020608|
#    489|   1088|   4.5| 2.5361385|
#     10|   1088|   3.0|  3.391657|
#    469|   1238|   5.0| 3.8878498|
# +------+-------+------+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### Model apply and see the performance

# %%
full_ratings_df = spark.read.load("/FileStore/tables/ratings_full.csv", format='csv', header = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
full_ratings_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+----------+
# userId|movieId|rating| timestamp|
# +------+-------+------+----------+
#      1|    307|   3.5|1256677221|
#      1|    481|   3.5|1256677456|
#      1|   1091|   1.5|1256677471|
#      1|   1257|   4.5|1256677460|
#      1|   1449|   4.5|1256677264|
#      1|   1590|   2.5|1256677236|
#      1|   1591|   1.5|1256677475|
#      1|   2134|   4.5|1256677464|
#      1|   2478|   4.0|1256677239|
#      1|   2840|   3.0|1256677500|
#      1|   2986|   2.5|1256677496|
#      1|   3020|   4.0|1256677260|
#      1|   3424|   4.5|1256677444|
#      1|   3698|   3.5|1256677243|
#      1|   3826|   2.0|1256677210|
#      1|   3893|   3.5|1256677486|
#      2|    170|   3.5|1192913581|
#      2|    849|   3.5|1192913537|
#      2|   1186|   3.5|1192913611|
#      2|   1235|   3.0|1192913585|
# +------+-------+------+----------+
# only showing top 20 rows
#
# </div>

# %%
all_ratings=full_ratings_df.drop('timestamp')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
all_ratings.registerTempTable("all_ratings")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/dataframe.py:141: DeprecationWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   &#34;Deprecated in 2.0, use createOrReplaceTempView instead.&#34;, DeprecationWarning)
# </div>

# %%
# %sql
select count(*)
from all_ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>27753444</td></tr></tbody></table></div>

# %%
# %sql
select * from all_ratings where movieId=463
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th></tr></thead><tbody><tr><td>114</td><td>463</td><td>4.0</td></tr><tr><td>758</td><td>463</td><td>3.0</td></tr><tr><td>1927</td><td>463</td><td>2.0</td></tr><tr><td>2481</td><td>463</td><td>3.0</td></tr><tr><td>2629</td><td>463</td><td>2.5</td></tr><tr><td>3246</td><td>463</td><td>3.0</td></tr><tr><td>3832</td><td>463</td><td>3.0</td></tr><tr><td>4796</td><td>463</td><td>2.0</td></tr><tr><td>5276</td><td>463</td><td>4.0</td></tr><tr><td>5323</td><td>463</td><td>3.0</td></tr><tr><td>6168</td><td>463</td><td>2.0</td></tr><tr><td>6657</td><td>463</td><td>3.0</td></tr><tr><td>6826</td><td>463</td><td>3.0</td></tr><tr><td>7427</td><td>463</td><td>3.0</td></tr><tr><td>8210</td><td>463</td><td>3.0</td></tr><tr><td>9248</td><td>463</td><td>4.0</td></tr><tr><td>9363</td><td>463</td><td>1.0</td></tr><tr><td>11048</td><td>463</td><td>4.0</td></tr><tr><td>11210</td><td>463</td><td>3.0</td></tr><tr><td>11752</td><td>463</td><td>4.0</td></tr><tr><td>12951</td><td>
# %%
from pyspark.sql.types import IntegerType, FloatType
all_ratings = all_ratings.withColumn("userId", all_ratings["userId"].cast(IntegerType()))
all_ratings = all_ratings.withColumn("movieId", all_ratings["movieId"].cast(IntegerType()))
all_ratings = all_ratings.withColumn("rating", all_ratings["rating"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# #Fit best model to full data
# Define evaluator as RMSE
alldata= best_model.transform(all_ratings)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(alldata)
print("Root-mean-square error = " + str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root-mean-square error = 1.191330329854964
# </div>

# %%
alldata.registerTempTable("alldata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
alldata.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+----------+
# userId|movieId|rating|prediction|
# +------+-------+------+----------+
#    165|    148|   3.0| 2.5097415|
#    251|    471|   3.0| 4.1424904|
#    593|    471|   3.0| 3.4580667|
#     81|    471|   3.5| 3.0215242|
#    332|    471|   2.0| 3.3657987|
#    336|    471|   4.0|   3.96483|
#    417|    471|   3.0| 4.2116575|
#    360|    471|   5.0| 5.2912974|
#    185|    471|   4.0| 3.5891848|
#    429|    471|   4.0| 4.2484083|
#    295|    471|   4.0| 3.6462588|
#    432|    471|   3.0| 3.7051258|
#    235|    471|   4.0|  3.904637|
#    609|    471|   3.0|  3.034154|
#    423|    471|   3.0|  3.498432|
#    485|    471|   4.0| 4.0383196|
#      4|    471|   4.5|  3.820769|
#    549|    471|   3.5|  3.528251|
#    277|    471|   3.5| 3.3533683|
#    428|    471|   5.0|  2.867961|
# +------+-------+------+----------+
# only showing top 20 rows
#
# </div>

# %%
# %sql
select count(*)
from alldata
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>60774</td></tr></tbody></table></div>

# %%
# %sql
select count(distinct movieId)
from all_ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT movieId)</th></tr></thead><tbody><tr><td>53889</td></tr></tbody></table></div>

# %%
# %sql
select count(distinct movieId)
from alldata
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT movieId)</th></tr></thead><tbody><tr><td>6198</td></tr></tbody></table></div>

# %%
# %sql
select * from alldata where movieId=463
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql select * from movies join alldata on movies.movieId=alldata.movieId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>148</td><td>Awfully Big Adventure, An (1995)</td><td>Drama</td><td>165</td><td>148</td><td>3.0</td><td>2.5097415</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>251</td><td>471</td><td>3.0</td><td>4.1424904</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>593</td><td>471</td><td>3.0</td><td>3.4580667</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>81</td><td>471</td><td>3.5</td><td>3.0215242</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>332</td><td>471</td><td>2.0</td><td>3.3657987</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>336</td><td>471</td><td>4.0</td><td>3.96483</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>417</td><td>471</td><td>3.0</td><td>4.2116575</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>360</td><td>471</td><td>5.0</td><td>5.2912974</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>185</td><td>471</td><td>4.0</td><td>3.5891848</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>429</td><td>471</td><td>4.0</td><td>4.2484083</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>295</td><td>471</td><td>4.0</td><td>3.6462588</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>432</td><td>471</td><td>3.0</td><td>3.7051258</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>235</td><td>471</td><td>4.0</td><td>3.904637</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>609</td><td>471</td><td>3.0</td><td>3.034154</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>423</td><td>471</td><td>3.0</td><td>3.498432</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>485</td><td>471</td><td>4.0</td><td>4.0383196</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>4</td><td>471</td><td>4.5</td><td>3.820769</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>549</td><td>471</td><td>3.5</td><td>3.528251</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>277</td><td>471</td><td>3.5</td><td>3.3533683</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>428</td><td>471</td><td>5.0</td><td>2.867961</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>239</td><td>471</td><td>4.0</td><td>3.8658423</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>240</td><td>471</td><td>5.0</td><td>3.0365252</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>356</td><td>471</td><td>3.5</td><td>3.810369</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>73</td><td>471</td><td>4.0</td><td>3.8330855</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>214</td><td>471</td><td>4.0</td><td>2.7025647</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>79</td><td>471</td><td>5.0</td><td>3.8033204</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>605</td><td>471</td><td>1.0</td><td>2.9785194</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>252</td><td>471</td><td>4.0</td><td>4.0427666</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>138</td><td>471</td><td>4.0</td><td>2.420904</td></tr><tr><td>833</td><td>High School High (1996)</td><td>Comedy</td><td>185</td><td>833</td><td>3.0</td><td>1.8569182 ...

# %% [markdown]
# ## Recommend moive to users with id: 575 and 232.
# you can choose some users to recommend the moives

# %%
randomuser_recs=best_model.recommendForAllUsers(20).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+
# userId|     recommendations|
# +------+--------------------+
#    471|[[3379, 5.255083]...|
#    463|[[104875, 5.53258...|
#    496|[[40491, 5.678574...|
#    148|[[104875, 5.23928...|
#    540|[[104875, 5.90487...|
#    392|[[26171, 6.600666...|
#    243|[[26171, 8.091344...|
#     31|[[104875, 5.77406...|
#    516|[[26171, 5.950064...|
#    580|[[104875, 5.39512...|
# +------+--------------------+
# only showing top 10 rows
#
# </div>

# %%
 user_subset = alldata.where(alldata.userId.isin('575', '232'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
user_recs=best_model.recommendForUserSubset(user_subset,10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
user_recs.registerTempTable("user_recs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
user_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+
# userId|     recommendations|
# +------+--------------------+
#    232|[[104875, 5.20441...|
#    575|[[40491, 6.14295]...|
# +------+--------------------+
#
# </div>

# %%
user_recs.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- userId: integer (nullable = false)
# -- recommendations: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- movieId: integer (nullable = true)
#     |    |-- rating: float (nullable = true)
#
# </div>

# %%
user_recs =user_recs.select(user_recs.userId,explode(user_recs.recommendations).alias("recommendations"))
user_recs.printSchema()
user_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- userId: integer (nullable = false)
# -- recommendations: struct (nullable = true)
#     |-- movieId: integer (nullable = true)
#     |-- rating: float (nullable = true)
#
# +------+-------------------+
# userId|    recommendations|
# +------+-------------------+
#    232| [104875, 5.204411]|
#    232|   [3379, 4.951416]|
#    232| [59018, 4.9338446]|
#    232| [60943, 4.9338446]|
#    232| [77846, 4.9050493]|
#    232| [93008, 4.9050493]|
#    232| [25906, 4.9050493]|
#    232| [67618, 4.8008194]|
#    232|[102217, 4.7856746]|
#    232| [33779, 4.7856746]|
#    575|   [40491, 6.14295]|
#    575|   [6818, 6.105632]|
#    575| [26326, 6.0445323]|
#    575| [148881, 5.920022]|
#    575|  [25947, 5.904063]|
#    575|   [3379, 5.814243]|
#    575|   [2936, 5.803298]|
#    575|   [6201, 5.768714]|
#    575|  [7926, 5.7504706]|
#    575|  [102217, 5.74046]|
# +------+-------------------+
#
# </div>

# %%
user_recs = user_recs.select(user_recs["userId"], user_recs["recommendations.movieId"], user_recs["recommendations.rating"])
user_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+---------+
# userId|movieId|   rating|
# +------+-------+---------+
#    232| 104875| 5.204411|
#    232|   3379| 4.951416|
#    232|  59018|4.9338446|
#    232|  60943|4.9338446|
#    232|  77846|4.9050493|
#    232|  93008|4.9050493|
#    232|  25906|4.9050493|
#    232|  67618|4.8008194|
#    232| 102217|4.7856746|
#    232|  33779|4.7856746|
#    575|  40491|  6.14295|
#    575|   6818| 6.105632|
#    575|  26326|6.0445323|
#    575| 148881| 5.920022|
#    575|  25947| 5.904063|
#    575|   3379| 5.814243|
#    575|   2936| 5.803298|
#    575|   6201| 5.768714|
#    575|   7926|5.7504706|
#    575| 102217|  5.74046|
# +------+-------+---------+
#
# </div>

# %%
user_recs.registerTempTable("user_recs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql 
select userId, movies.movieId, title, rating from movies join user_recs on movies.movieId=user_recs.movieId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>title</th><th>rating</th></tr></thead><tbody><tr><td>232</td><td>104875</td><td>History of Future Folk, The (2012)</td><td>5.204411</td></tr><tr><td>232</td><td>3379</td><td>On the Beach (1959)</td><td>4.951416</td></tr><tr><td>232</td><td>59018</td><td>Visitor, The (2007)</td><td>4.9338446</td></tr><tr><td>232</td><td>60943</td><td>Frozen River (2008)</td><td>4.9338446</td></tr><tr><td>232</td><td>77846</td><td>12 Angry Men (1997)</td><td>4.9050493</td></tr><tr><td>232</td><td>93008</td><td>Very Potter Sequel, A (2010)</td><td>4.9050493</td></tr><tr><td>232</td><td>25906</td><td>Mr. Skeffington (1944)</td><td>4.9050493</td></tr><tr><td>232</td><td>67618</td><td>Strictly Sexual (2008)</td><td>4.8008194</td></tr><tr><td>232</td><td>102217</td><td>Bill Hicks: Revelations (1993)</td><td>4.7856746</td></tr><tr><td>232</td><td>33779</td><td>Eddie Izzard: Dress to Kill (1999)</td><td>4.7856746</td></tr><tr><td>575</td><td>40491</td><td>Match Factory Girl, The (Tulitikkutehtaan tyttö) (1990)</td><td>6.14295</td></tr><tr><td>575</td><td>6818</td><td>Come and See (Idi i smotri) (1985)</td><td>6.105632</td></tr><tr><td>575</td><td>26326</td><td>Holy Mountain, The (Montaña sagrada, La) (1973)</td><td>6.0445323</td></tr><tr><td>575</td><td>148881</td><td>World of Tomorrow (2015)</td><td>5.920022</td></tr><tr><td>575</td><td>25947</td><td>Unfaithfully Yours (1948)</td><td>5.904063</td></tr><tr><td>575</td><td>3379</td><td>On the Beach (1959)</td><td>5.814243</td></tr><tr><td>575</td><td>2936</td><td>Sullivan's Travels (1941)</td><td>5.803298</td></tr><tr><td>575</td><td>6201</td><td>Lady Jane (1986)</td><td>5.768714</td></tr><tr><td>575</td><td>7926</td><td>High and Low (Tengoku to jigoku) (1963)</td><td>5.7504706</td></tr><tr><td>575</td><td>102217</td><td>Bill Hicks: Revelations (1993)</td><td>5.74046</td></tr></tbody></table></div>

# %% [markdown]
# ## Find the similar moives for moive with id: 463, 471
# You can find the similar moives based on the ALS results

# %%
item_subset = alldata.where(alldata.movieId.isin(463, 471))
item_recs=best_model.recommendForItemSubset(item_subset, 100)
item_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+
# movieId|     recommendations|
# +-------+--------------------+
#     471|[[360, 5.2912974]...|
# +-------+--------------------+
#
# </div>

# %%
item_recs =item_recs.select(item_recs.movieId,explode(item_recs.recommendations).alias("recommendations"))
item_recs.printSchema()
item_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- movieId: integer (nullable = false)
# -- recommendations: struct (nullable = true)
#     |-- userId: integer (nullable = true)
#     |-- rating: float (nullable = true)
#
# +-------+----------------+
# movieId| recommendations|
# +-------+----------------+
#     471|[360, 5.2912974]|
#     471| [558, 4.966321]|
#     471|  [99, 4.794973]|
#     471|[258, 4.7661834]|
#     471| [53, 4.7304034]|
#     471|[250, 4.6426454]|
#     471|[538, 4.6003923]|
#     471| [12, 4.5880632]|
#     471| [515, 4.568069]|
#     471|[188, 4.5572786]|
#     471|[171, 4.5375347]|
#     471|[494, 4.5316296]|
#     471|  [20, 4.511927]|
#     471|[554, 4.4971166]|
#     471| [25, 4.4763136]|
#     471|[371, 4.4747005]|
#     471|[389, 4.4644575]|
#     471|   [1, 4.455026]|
#     471| [108, 4.446908]|
#     471|[224, 4.4293895]|
# +-------+----------------+
# only showing top 20 rows
#
# </div>

# %%
item_recs = item_recs.select(item_recs["movieId"], item_recs["recommendations.userId"], item_recs["recommendations.rating"])
item_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------+---------+
# movieId|userId|   rating|
# +-------+------+---------+
#     471|   360|5.2912974|
#     471|   558| 4.966321|
#     471|    99| 4.794973|
#     471|   258|4.7661834|
#     471|    53|4.7304034|
#     471|   250|4.6426454|
#     471|   538|4.6003923|
#     471|    12|4.5880632|
#     471|   515| 4.568069|
#     471|   188|4.5572786|
#     471|   171|4.5375347|
#     471|   494|4.5316296|
#     471|    20| 4.511927|
#     471|   554|4.4971166|
#     471|    25|4.4763136|
#     471|   371|4.4747005|
#     471|   389|4.4644575|
#     471|     1| 4.455026|
#     471|   108| 4.446908|
#     471|   224|4.4293895|
# +-------+------+---------+
# only showing top 20 rows
#
# </div>

# %%
item_recs.registerTempTable("item_recs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql 
select  movies.movieId, title, userId, rating from movies join item_recs on movies.movieId=item_recs.movieId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>userId</th><th>rating</th></tr></thead><tbody><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>360</td><td>5.2912974</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>558</td><td>4.966321</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>99</td><td>4.794973</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>258</td><td>4.7661834</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>53</td><td>4.7304034</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>250</td><td>4.6426454</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>538</td><td>4.6003923</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>12</td><td>4.5880632</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>515</td><td>4.568069</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>188</td><td>4.5572786</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>171</td><td>4.5375347</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>494</td><td>4.5316296</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>20</td><td>4.511927</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>554</td><td>4.4971166</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>25</td><td>4.4763136</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>371</td><td>4.4747005</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>389</td><td>4.4644575</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>1</td><td>4.455026</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>108</td><td>4.446908</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>224</td><td>4.4293895</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>122</td><td>4.3976536</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>106</td><td>4.396768</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>40</td><td>4.378996</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>11</td><td>4.3766193</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>553</td><td>4.3734565</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>575</td><td>4.3681946</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>459</td><td>4.352131</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>523</td><td>4.3424854</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>35</td><td>4.3372207</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>348</td><td>4.312279</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>364</td><td>4.301868</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>382</td><td>4.301058</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>375</td><td>4.2969875</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>162</td><td>4.292256</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>69</td><td>4.287436</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>465</td><td>4.2791433</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>398</td><td>4.269382</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>30</td><td>4.2675695</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>452</td><td>4.2660747</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>383</td><td>4.263003</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>373</td><td>4.258891</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>542</td><td>4.249895</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>429</td><td>4.2484083</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>169</td><td>4.248046</td></tr><tr><td> ...

# %% [markdown]
# ## Write the report
# motivation
# 1. step1
# 2. step2
# 3. step3
# 4. step4
# output and conclusion

# %% [markdown]
# # 老师我主要的问题就是cmd 70-80这里的用完als模型以后数据丢失的问题
